# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. The followings are the problems that continue from previous assignments (assignment 7).

# %%
world = pd.read_csv("data/7. world_small.csv", index_col="country", dtype={"gdppcap08":np.float64, "polityIV":np.float64})
afr = world.loc[world['region']=='Africa', ['polityIV']]

# %% [markdown]
# (1)	Add a variable called 'population', which is generated by the following code,
# to the 'afr' dataframe created in assignment 7.
# ```
# np.random.randint(1000, 5000, len(afr))
# ```

# %%
afr['population'] = np.random.randint(1000, 5000, len(afr))
afr.head()
# Out:
#               polityIV  population
# country
# Algeria           10.0        3402
# Angola             8.0        4640
# Benin             16.2        2555
# Botswana          19.0        2381
# Burkina Faso      10.0        2529

# %% [markdown]
# (2)	Add a variable named 'gdp' created by multiplying the 'gdppcap08' of 'world' data by the 'population' of 'afr' data.
# There is no population value for the countries other than Africa so their 'gdp' values can not be obtained.
# For these cases, enter 0 instead of NaN.

# %%
world['gdp'] = afr['population'] * world['gdppcap08']
world['gdp'] = world['gdp'].fillna(0)
world.head()
# Out:
#                region  gdppcap08  polityIV         gdp
# country
# Albania    C&E Europe     7715.0      17.8         0.0
# Algeria        Africa     8033.0      10.0  27328266.0
# Angola         Africa     5899.0       8.0  27371360.0
# Argentina  S. America    14333.0      18.0         0.0
# Armenia    C&E Europe     6070.0      15.0         0.0

# %% [markdown]
# (3)	Add a variable called 'gdp_log' which is the natural log of 'gdppcap08' to 'world' data.

# %%
world['gdp_log'] = np.log(world['gdppcap08'])
world.head()
# Out:
#                region  gdppcap08  polityIV         gdp   gdp_log
# country
# Albania    C&E Europe     7715.0      17.8         0.0  8.950922
# Algeria        Africa     8033.0      10.0  27328266.0  8.991313
# Angola         Africa     5899.0       8.0  27371360.0  8.682538
# Argentina  S. America    14333.0      18.0         0.0  9.570320
# Armenia    C&E Europe     6070.0      15.0         0.0  8.711114

# %% [markdown]
# (4)	Select only variables 'gdppcap08' and 'polityIV' in 'world' data and store them as a dataframe called 'world_num',
# and then standardize them by variables (each element is subtracted from the average of the column containing the element
# and then divided by the standard deviation of the column).

# %%
world_num = world[['gdppcap08', 'polityIV']]
(world_num - world_num.mean()) / world_num.std()
# Out:
#                           gdppcap08  polityIV
# country
# Albania                   -0.374056  0.666732
# Algeria                   -0.352573 -0.517306
# Angola                    -0.496737 -0.820905
# Argentina                  0.073028  0.697092
# Armenia                   -0.485185  0.241693
# Australia                  1.514939  1.000692
# Austria                    1.682139  1.000692
# Azerbaijan                -0.303122 -1.579904
# Bahrain                    1.442519 -1.579904
# Bangladesh                -0.805129  0.393493
# Belarus                   -0.066947 -1.579904
# Belgium                    1.434953  1.000692
# Benin                     -0.796077  0.423853
# Bhutan                    -0.574021 -1.731704
# Bolivia                   -0.606245  0.727452
# Botswana                   0.009458  0.848892
# Brazil                    -0.199694  0.697092
# Bulgaria                  -0.058030  0.848892
# Burkina Faso              -0.816817 -0.517306
# ...

# %% [markdown]
# (5)	Add a variable called 'democ' to 'world' data,
# which is a dummy variable with a value of 1 if polityIV is greater than 10 and 0, otherwise.

# %%
world['democ'] = 1 * (world['polityIV'] > 10)
world.head()
# Out:
#                region  gdppcap08  polityIV         gdp   gdp_log  democ
# country
# Albania    C&E Europe     7715.0      17.8         0.0  8.950922      1
# Algeria        Africa     8033.0      10.0  27328266.0  8.991313      0
# Angola         Africa     5899.0       8.0  27371360.0  8.682538      0
# Argentina  S. America    14333.0      18.0         0.0  9.570320      1
# Armenia    C&E Europe     6070.0      15.0         0.0  8.711114      1

# %% [markdown]
# (6)	Arrange 'world' data so that the values of 'region' variable are in alphabetical order.
# Also, use 'gdppcap08' variable to arrange the data so that it is in ascending order if the 'region' values are the same.

# %%
world = world.sort_values(['region', 'gdppcap08'])
world.head()
# Out:
#                 region  gdppcap08  polityIV        gdp   gdp_log  democ
# country
# Zimbabwe        Africa      188.0       6.0   429956.0  5.236442      0
# Congo Kinshasa  Africa      321.0      15.0  1562307.0  5.771441      1
# Liberia         Africa      388.0      10.0  1649388.0  5.961005      0
# Guinea-Bissau   Africa      538.0      11.0   883396.0  6.287859      1
# Eritrea         Africa      632.0       3.0  1238720.0  6.448889      0

# %% [markdown]
# (7)	Extract 15 rows randomly from ‘world’ data without replacement. (비복원추출)

# %%
world.sample(15, replace=False)
# Out:
#                      region  gdppcap08  polityIV         gdp    gdp_log  democ
# country
# Belarus          C&E Europe    12261.0       3.0         0.0   9.414179      0
# Philippines    Asia-Pacific     3510.0      18.0         0.0   8.163371      1
# Spain             W. Europe    31954.0      20.0         0.0  10.372053      1
# Mozambique           Africa      855.0      16.0   3813300.0   6.751101      1
# Canada           N. America    36444.0      20.0         0.0  10.503532      1
# Honduras         S. America     3965.0      17.0         0.0   8.285261      1
# Algeria              Africa     8033.0      10.0  27328266.0   8.991313      0
# India          Asia-Pacific     2972.0      19.0         0.0   7.996990      1
# Guatemala        S. America     4760.0      18.0         0.0   8.468003      1
# Venezuela        S. America    12804.0      16.0         0.0   9.457513      1
# China          Asia-Pacific     5962.0       3.0         0.0   8.693161      0
# ...

# %% [markdown]
# 2. Using the dataset '8. automobile_data.csv', answer the following.

# %% [markdown]
# (1)	Read the dataset '8. automobile_data.csv' as a DataFrame called 'autodata'.

# %%
autodata = pd.read_csv("data/8. automobile_data.csv")
autodata
# Out:
#     index        company   body-style wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible       88.6   168.8        dohc
# 1       1    alfa-romero  convertible       88.6   168.8        dohc
# 2       2    alfa-romero    hatchback       94.5   171.2        ohcv
# 3       3           audi        sedan       99.8   176.6         ohc
# 4       4           audi        sedan       99.4   176.6         ohc
# 5       5           audi        sedan       99.8   177.3         ohc
# 6       6           audi        wagon      105.8   192.7         ohc
# 7       9            bmw        sedan          ?   176.8         ohc
# 8      10            bmw        sedan      101.2   176.8         ohc
# 9      11            bmw        sedan      101.2   176.8         ohc
# 10     13            bmw        sedan      103.5   189.0         ohc
# 11     14            bmw        sedan      103.5   193.8         ohc
# 12     15            bmw        sedan        110   197.0         ohc
# ...

# %% [markdown]
# (2)	Print the name and type of all the columns in 'autodata'.

# %%
autodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
# index               61 non-null int64
# company             61 non-null object
# body-style          61 non-null object
# wheel-base          61 non-null object
# length              61 non-null float64
# engine-type         61 non-null object
# num-of-cylinders    61 non-null object
# horsepower          61 non-null object
# average-mileage     61 non-null int64
# price               58 non-null float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 4.8+ KB

# %% [markdown]
# (3)	Print first five rows of 'autodata'.

# %%
autodata.head(5)
# Out:
#    index      company   body-style wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible       88.6   168.8        dohc
# 1      1  alfa-romero  convertible       88.6   168.8        dohc
# 2      2  alfa-romero    hatchback       94.5   171.2        ohcv
# 3      3         audi        sedan       99.8   176.6         ohc
# 4      4         audi        sedan       99.4   176.6         ohc
#
#   num-of-cylinders horsepower  average-mileage    price
# 0             four        111               21  13495.0
# 1             four        111               21  16500.0
# 2              six        154               19  16500.0
# 3             four        102               24  13950.0
# 4             five        115               18  17450.0

# %% [markdown]
# (4)	Replace all the values '?' in 'autodata' with NaN.

# %%
autodata.replace('?', np.nan, inplace=True)
autodata
# Out:
#     index        company   body-style wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible       88.6   168.8        dohc
# 1       1    alfa-romero  convertible       88.6   168.8        dohc
# 2       2    alfa-romero    hatchback       94.5   171.2        ohcv
# 3       3           audi        sedan       99.8   176.6         ohc
# 4       4           audi        sedan       99.4   176.6         ohc
# 5       5           audi        sedan       99.8   177.3         ohc
# 6       6           audi        wagon      105.8   192.7         ohc
# 7       9            bmw        sedan        NaN   176.8         ohc
# 8      10            bmw        sedan      101.2   176.8         ohc
# 9      11            bmw        sedan      101.2   176.8         ohc
# 10     13            bmw        sedan      103.5   189.0         ohc
# 11     14            bmw        sedan      103.5   193.8         ohc
# 12     15            bmw        sedan        110   197.0         ohc
# ...

# %% [markdown]
# (5)	Convert the type of the column 'wheel-base' and 'horsepower' to float64.
# Make sure that type of these variables has changed in the original 'autodata'.

# %%
autodata[['wheel-base', 'horsepower']] = autodata[['wheel-base', 'horsepower']].astype(np.float64)
autodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
# index               61 non-null int64
# company             61 non-null object
# body-style          60 non-null object
# wheel-base          60 non-null float64
# length              61 non-null float64
# engine-type         60 non-null object
# num-of-cylinders    59 non-null object
# horsepower          60 non-null float64
# average-mileage     61 non-null int64
# price               58 non-null float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# (6)	Print most expensive car's company name and price.

# %%
autodata.loc[autodata['price']==autodata['price'].max(), ['company', 'price']]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# (7)	Print All 'toyota' Cars details.

# %%
autodata[autodata['company']=='toyota']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48        62.0               35   5348.0
# 49        62.0               31   6338.0
# 50        62.0               31   6488.0
# 51        62.0               31   6918.0
# 52        62.0               27   7898.0
# 53        62.0               27   8778.0
# 54         NaN               19  15750.0

# %% [markdown]
# (8)	Count total cars per company.

# %%
autodata.groupby('company').apply(len)
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# dtype: int64

# %% [markdown]
# (9)	Find each company’s highest price car

# %%
max_price = autodata.groupby('company')['price'].apply(max)
print(max_price)
car_df1 = pd.DataFrame()
car_df2 = pd.DataFrame()
for i,j in enumerate(max_price):
    company = max_price.keys()[i]
    price = j
    if car_df1.empty:
        car_df1 = autodata[(autodata['company']==company)&(autodata['price']==j)]
    else:
        car_df2 = autodata[(autodata['company']==company)&(autodata['price']==j)]
        car_df1 = pd.concat([car_df1, car_df2])
car_df1
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64
#     index        company   body-style  wheel-base  length engine-type  \
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 6       6           audi        wagon       105.8   192.7         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# ...

# %% [markdown]
# (10) Find the mean of 'average-mileage' of each car making company.

# %%
autodata.groupby('company')['average-mileage'].mean()
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %% [markdown]
# (11) Compute how many non-missing values there are for each column.

# %%
autodata.count()
# Out:
# index               61
# company             61
# body-style          60
# wheel-base          60
# length              61
# engine-type         60
# num-of-cylinders    59
# horsepower          60
# average-mileage     61
# price               58
# dtype: int64

# %% [markdown]
# 3. Using the dataset '8. student_alc.csv', answer the following.

# %% [markdown]
# (1)	Read the dataset '8. student_alc.csv' as a DataFrame called 'stdalc'.

# %%
stdalc = pd.read_csv('data/8. student_alc.csv')
stdalc
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# (2)	What is the name of 17th column?

# %%
stdalc.columns[16]
# Out:
# 'famsup'

# %% [markdown]
# (3)	Delete the 'address' column in place.

# %%
stdalc.drop(columns='address', inplace=True)
stdalc.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  ...  \
# 0     GP   F   18     GT3       A     4     4  at_home   teacher  course  ...
# 1     GP   F   17     GT3       T     1     1  at_home     other  course  ...
# 2     GP   F   15     LE3       T     1     1  at_home     other   other  ...
# 3     GP   F   15     GT3       T     4     2   health  services    home  ...
# 4     GP   F   16     GT3       T     3     3    other     other    home  ...
#
#   famrel  freetime  goout  Dalc Walc health absences  G1  G2  G3
# 0      4         3      4     1    1      3        6   5   6   6
# 1      5         3      3     1    1      3        4   5   5   6
# 2      4         3      2     2    3      3       10   7   8  10
# 3      3         2      2     1    1      5        2  15  14  15
# 4      4         3      2     1    2      5        4   6  10  10
#
# [5 rows x 32 columns]

# %% [markdown]
# (4)	Convert all the letters for the columns 'Mjob' and 'Fjob' to upper case letters.

# %%
stdalc[['Mjob', 'Fjob']] = stdalc[['Mjob', 'Fjob']].apply(lambda x: x.apply(lambda y: y.upper()))
stdalc.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  ...  \
# 0     GP   F   18     GT3       A     4     4  AT_HOME   TEACHER  course  ...
# 1     GP   F   17     GT3       T     1     1  AT_HOME     OTHER  course  ...
# 2     GP   F   15     LE3       T     1     1  AT_HOME     OTHER   other  ...
# 3     GP   F   15     GT3       T     4     2   HEALTH  SERVICES    home  ...
# 4     GP   F   16     GT3       T     3     3    OTHER     OTHER    home  ...
#
#   famrel  freetime  goout  Dalc Walc health absences  G1  G2  G3
# 0      4         3      4     1    1      3        6   5   6   6
# 1      5         3      3     1    1      3        4   5   5   6
# 2      4         3      2     2    3      3       10   7   8  10
# 3      3         2      2     1    1      5        2  15  14  15
# 4      4         3      2     1    2      5        4   6  10  10
#
# [5 rows x 32 columns]

# %%
stdalc[['Mjob', 'Fjob']] = pd.concat([stdalc['Mjob'].str.upper(), stdalc['Fjob'].str.upper()], axis=1)
stdalc.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  ...  \
# 0     GP   F   18     GT3       A     4     4  AT_HOME   TEACHER  course  ...
# 1     GP   F   17     GT3       T     1     1  AT_HOME     OTHER  course  ...
# 2     GP   F   15     LE3       T     1     1  AT_HOME     OTHER   other  ...
# 3     GP   F   15     GT3       T     4     2   HEALTH  SERVICES    home  ...
# 4     GP   F   16     GT3       T     3     3    OTHER     OTHER    home  ...
#
#   famrel  freetime  goout  Dalc Walc health absences  G1  G2  G3
# 0      4         3      4     1    1      3        6   5   6   6
# 1      5         3      3     1    1      3        4   5   5   6
# 2      4         3      2     2    3      3       10   7   8  10
# 3      3         2      2     1    1      5        2  15  14  15
# 4      4         3      2     1    2      5        4   6  10  10
#
# [5 rows x 32 columns]

# %% [markdown]
# (5)	Create a new column called 'legal_drinker'
# which consists of True if age is older than 18 years old and False otherwise.

# %%
stdalc['legal_drinker'] = stdalc['age'] > 18
stdalc.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  ...  \
# 0     GP   F   18     GT3       A     4     4  AT_HOME   TEACHER  course  ...
# 1     GP   F   17     GT3       T     1     1  AT_HOME     OTHER  course  ...
# 2     GP   F   15     LE3       T     1     1  AT_HOME     OTHER   other  ...
# 3     GP   F   15     GT3       T     4     2   HEALTH  SERVICES    home  ...
# 4     GP   F   16     GT3       T     3     3    OTHER     OTHER    home  ...
#
#   freetime  goout  Dalc  Walc health absences  G1  G2  G3 legal_drinker
# 0        3      4     1     1      3        6   5   6   6         False
# 1        3      3     1     1      3        4   5   5   6         False
# 2        3      2     2     3      3       10   7   8  10         False
# 3        2      2     1     1      5        2  15  14  15         False
# 4        3      2     1     2      5        4   6  10  10         False
#
# [5 rows x 33 columns]

# %% [markdown]
# 4. Using the dataset '8. users.csv', answer the following.

# %% [markdown]
# (1)	Read the dataset '8. users.csv' as a DataFrame called 'users'.

# %%
users = pd.read_csv('data/8. users.csv')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 17        18   35      F          other    37212
# ...

# %% [markdown]
# (2)	Discover what is the mean 'age' per 'occupation'.

# %%
users.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# (3)	Discover the Male ratio per 'occupation' and sort it from the most to the least.

# %%
temp = pd.concat([users['gender']=='M', users['occupation']], axis=1)
temp.groupby('occupation')['gender'].mean().sort_values(ascending=False)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: gender, dtype: float64

# %% [markdown]
# (4)	For each combination of occupation and gender, calculate the minimum, mean and maximum ages.

# %%
users.groupby(['occupation', 'gender'])['age'].agg([min, np.mean, max])
# Out:
#                       min       mean  max
# occupation    gender
# administrator F        22  40.638889   62
#               M        21  37.162791   70
# artist        F        19  30.307692   48
#               M        20  32.333333   45
# doctor        M        28  43.571429   64
# educator      F        23  39.115385   51
#               M        25  43.101449   63
# engineer      F        23  29.500000   36
#               M        22  36.600000   70
# entertainment F        24  31.000000   38
#               M        15  29.000000   50
# executive     F        39  44.000000   49
#               M        22  38.172414   69
# healthcare    F        22  39.818182   53
#               M        28  45.400000   62
# homemaker     F        20  34.166667   50
#               M        23  23.000000   23
# lawyer        F        28  39.500000   51
#               M        21  36.200000   53
# librarian     F        26  40.000000   59
#               M        23  40.000000   69
# ...
