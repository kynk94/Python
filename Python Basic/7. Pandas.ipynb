# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ※ The world_small.csv data contains the region, GDP per capita (gdppcap08),
# and polity score (polityIV) of each country in the world.

# %% [markdown]
# 1. Read this data and create a DataFrame object called 'world'.
# Make sure that the variable 'country' is the index,
# and the labels in the first row of data is the columns of the DataFrame.
# Also, make sure 'gdppcap08' and 'polityIV' are both stored in np.float64 type.

# %%
world = pd.read_csv("7. world_small.csv", index_col="country", dtype={"gdppcap08":np.float64, "polityIV":np.float64})
print(world.dtypes)
world
# Out:
# region        object
# gdppcap08    float64
# polityIV     float64
# dtype: object
#                                 region  gdppcap08   polityIV
# country
# Albania                     C&E Europe     7715.0  17.800000
# Algeria                         Africa     8033.0  10.000000
# Angola                          Africa     5899.0   8.000000
# Argentina                   S. America    14333.0  18.000000
# Armenia                     C&E Europe     6070.0  15.000000
# Australia                 Asia-Pacific    35677.0  20.000000
# Austria                      W. Europe    38152.0  20.000000
# Azerbaijan                  C&E Europe     8765.0   3.000000
# Bahrain                    Middle East    34605.0   3.000000
# Bangladesh                Asia-Pacific     1334.0  16.000000
# Belarus                     C&E Europe    12261.0   3.000000
# Belgium                      W. Europe    34493.0  20.000000
# Benin                           Africa     1468.0  16.200000
# ...

# %% [markdown]
# 2. Select only the countries with their 'polityIV' are in the bottom 10%
# and save their information as a DataFrame called btm10.

# %%
btm10 = world[world['polityIV']<=np.percentile(world['polityIV'],10)]
btm10
# Out:
#                     region  gdppcap08  polityIV
# country
# Azerbaijan      C&E Europe     8765.0       3.0
# Bahrain        Middle East    34605.0       3.0
# Belarus         C&E Europe    12261.0       3.0
# Bhutan        Asia-Pacific     4755.0       2.0
# China         Asia-Pacific     5962.0       3.0
# Cuba            S. America     9500.0       3.0
# Eritrea             Africa      632.0       3.0
# Iraq           Middle East     3570.0       1.0
# Kuwait         Middle East    39914.0       3.0
# Laos          Asia-Pacific     2134.0       3.0
# Libya          Middle East    15402.0       3.0
# Oman           Middle East    22478.0       2.0
# Qatar          Middle East    85868.0       0.0
# Saudi Arabia   Middle East    23920.0       0.0
# Swaziland           Africa     4928.0       1.0
# Turkmenistan    C&E Europe     6641.0       1.0
# UAE            Middle East    38830.0       2.0
# Uzbekistan      C&E Europe     2656.0       1.0
# ...

# %% [markdown]
# 3. Select only the polityIV variable of the country in Africa and save it as a data frame called afr.

# %%
afr = world.loc[world['region']=='Africa',['polityIV']]
afr
# Out:
#                            polityIV
# country
# Algeria                   10.000000
# Angola                     8.000000
# Benin                     16.200000
# Botswana                  19.000000
# Burkina Faso              10.000000
# Cameroon                   6.000000
# Central African Republic  10.200000
# Chad                       8.000000
# Comoros                   15.800000
# Congo Brazzaville          6.000000
# Congo Kinshasa            15.000000
# Djibouti                  12.000000
# Equatorial Guinea          5.000000
# Eritrea                    3.000000
# Gabon                      6.000000
# Gambia                     5.000000
# Ghana                     16.666667
# Guinea                     9.000000
# Guinea-Bissau             11.000000
# Kenya                     18.000000
# Lesotho                   18.000000
# Liberia                   10.000000
# Madagascar                17.000000
# Malawi                    15.000000
# Mali                      16.000000
# ...

# %% [markdown]
# 4. print the row indices of the countries in S. America. Use np.nonzero.

# %%
np.nonzero(world['region']=='S. America')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:56: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   return getattr(obj, method)(*args, **kwds)
# (array([  3,  14,  16,  24,  26,  30,  32,  36,  38,  51,  54,  55,  56,
#          65,  95, 102, 103, 138, 140], dtype=int64),)

# %% [markdown]
# 5. The following 3 expressions are for selecting the last two columns ('gdppcap08' and 'polityIV').
# Fill the blanks.

# %% [markdown]
# ①	world [ __________________________ ]

# %%
world[['gdppcap08', 'polityIV']]
# Out:
#                           gdppcap08   polityIV
# country
# Albania                      7715.0  17.800000
# Algeria                      8033.0  10.000000
# Angola                       5899.0   8.000000
# Argentina                   14333.0  18.000000
# Armenia                      6070.0  15.000000
# Australia                   35677.0  20.000000
# Austria                     38152.0  20.000000
# Azerbaijan                   8765.0   3.000000
# Bahrain                     34605.0   3.000000
# Bangladesh                   1334.0  16.000000
# Belarus                     12261.0   3.000000
# Belgium                     34493.0  20.000000
# Benin                        1468.0  16.200000
# Bhutan                       4755.0   2.000000
# Bolivia                      4278.0  18.200000
# Botswana                    13392.0  19.000000
# Brazil                      10296.0  18.000000
# Bulgaria                    12393.0  19.000000
# Burkina Faso                 1161.0  10.000000
# ...

# %% [markdown]
# ②	world.iloc [ __________________________ ]

# %%
world.iloc[:, 1:3]
# Out:
#                           gdppcap08   polityIV
# country
# Albania                      7715.0  17.800000
# Algeria                      8033.0  10.000000
# Angola                       5899.0   8.000000
# Argentina                   14333.0  18.000000
# Armenia                      6070.0  15.000000
# Australia                   35677.0  20.000000
# Austria                     38152.0  20.000000
# Azerbaijan                   8765.0   3.000000
# Bahrain                     34605.0   3.000000
# Bangladesh                   1334.0  16.000000
# Belarus                     12261.0   3.000000
# Belgium                     34493.0  20.000000
# Benin                        1468.0  16.200000
# Bhutan                       4755.0   2.000000
# Bolivia                      4278.0  18.200000
# Botswana                    13392.0  19.000000
# Brazil                      10296.0  18.000000
# Bulgaria                    12393.0  19.000000
# Burkina Faso                 1161.0  10.000000
# ...

# %% [markdown]
# ③	world.loc [ __________________________ ]

# %%
world.loc[:, ['gdppcap08','polityIV']]
# Out:
#                           gdppcap08   polityIV
# country
# Albania                      7715.0  17.800000
# Algeria                      8033.0  10.000000
# Angola                       5899.0   8.000000
# Argentina                   14333.0  18.000000
# Armenia                      6070.0  15.000000
# Australia                   35677.0  20.000000
# Austria                     38152.0  20.000000
# Azerbaijan                   8765.0   3.000000
# Bahrain                     34605.0   3.000000
# Bangladesh                   1334.0  16.000000
# Belarus                     12261.0   3.000000
# Belgium                     34493.0  20.000000
# Benin                        1468.0  16.200000
# Bhutan                       4755.0   2.000000
# Bolivia                      4278.0  18.200000
# Botswana                    13392.0  19.000000
# Brazil                      10296.0  18.000000
# Bulgaria                    12393.0  19.000000
# Burkina Faso                 1161.0  10.000000
# ...

# %% [markdown]
# 6. Replace all the 'polityIV' values which are greater than or equal to 20 as NaN.

# %%
world.loc[world['polityIV']>=20,['polityIV']] = np.nan
world
# Out:
#                                 region  gdppcap08   polityIV
# country
# Albania                     C&E Europe     7715.0  17.800000
# Algeria                         Africa     8033.0  10.000000
# Angola                          Africa     5899.0   8.000000
# Argentina                   S. America    14333.0  18.000000
# Armenia                     C&E Europe     6070.0  15.000000
# Australia                 Asia-Pacific    35677.0        NaN
# Austria                      W. Europe    38152.0        NaN
# Azerbaijan                  C&E Europe     8765.0   3.000000
# Bahrain                    Middle East    34605.0   3.000000
# Bangladesh                Asia-Pacific     1334.0  16.000000
# Belarus                     C&E Europe    12261.0   3.000000
# Belgium                      W. Europe    34493.0        NaN
# Benin                           Africa     1468.0  16.200000
# Bhutan                    Asia-Pacific     4755.0   2.000000
# ...
